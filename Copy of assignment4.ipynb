# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/exams.csv")

# %%
data
# Out:
#      gender  race/ethnicity  parental level of education         lunch  \
# 0         1               0                            2      standard
# 1         0               3                            5  free/reduced
# 2         1               4                            4  free/reduced
# 3         1               1                            2      standard
# 4         1               4                            0      standard
# ..      ...             ...                          ...           ...
# 995       1               2                            2      standard
# 996       1               3                            0  free/reduced
# 997       0               2                            5  free/reduced
# 998       0               2                            4      standard
# 999       1               0                            4      standard
#
#     test preparation course  math score  reading score  writing score
# 0                 completed        67.0           67.0             38
# 1                      none        40.0           59.0             30
# 2                      none        59.0           60.0             25
# 3                      none        77.0           78.0             43
# 4                 completed        78.0           73.0             43
# ..                      ...         ...            ...            ...
# 995                    none        73.0           70.0             40
# 996               completed        85.0           91.0             67
# 997                    none        32.0           35.0             16
# 998                    none        73.0           74.0             57
# 999               completed        65.0           60.0             37
#
# [1000 rows x 8 columns]

# %%
data["gender"].mode()
data["gender"].fillna("male", inplace=True)

# %%
data["math score"].mean()
data["math score"].fillna("66.3807", inplace=True)

# %%
data["reading score"].mean()
data["reading score"].fillna("69.0482", inplace=True)

# %%
data["writing score"].mean()
data["writing score"].fillna("67.7447", inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

# %%
data['gender'] = le.fit_transform(data['gender'])
data['race/ethnicity'] = le.fit_transform(data['race/ethnicity'])
data['parental level of education'] = le.fit_transform(data['parental level of education'])
data['lunch'] = le.fit_transform(data['lunch'])
data['test preparation course'] = le.fit_transform(data['test preparation course'])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Split features and target
X = data.drop(columns=['writing score'])
y = data['writing score']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Define the Decision Tree classifier with desired parameters
classifier = DecisionTreeClassifier(max_depth=5, criterion='gini')

# Train the classifier
classifier.fit(X_train, y_train)

# Predict on the test set
y_pred = classifier.predict(X_test)

# %%
y_test
# Out:
# 521    57
# 737    56
# 740    26
# 660    72
# 411    47
#        ..
# 109     8
# 430    60
# 77     56
# 84     14
# 286    59
# Name: writing score, Length: 250, dtype: int64

# %%
y_pred
# Out:
# array([52, 55, 22, 59, 50, 46, 75, 55, 55, 55, 38, 38, 28, 46, 15, 15, 55,
#        55, 55, 55, 31, 50, 41, 59, 40, 59, 55, 52, 41, 38, 55, 46, 23, 55,
#        46, 38, 40, 55, 40, 23, 36, 75, 22, 37, 15, 55, 38, 46, 38, 41, 38,
#        22, 22, 41, 31, 55, 38, 55, 40, 55, 23, 28, 64, 38, 70, 59, 63, 28,
#        38, 36, 15, 55, 57, 38, 46, 41, 75, 55, 46, 38, 37, 37, 55, 23, 64,
#        22, 46, 46, 37, 41, 55, 28, 46, 36, 55, 46, 52, 23, 55, 70, 64, 23,
#        23, 55, 55, 22, 52, 55, 64, 46, 36, 41, 46, 75, 57, 46, 55, 22, 52,
#        36, 15, 55, 31, 41, 63, 23, 55, 46, 57, 55, 64, 41, 46, 46, 38, 36,
#        46, 31, 22, 41, 59, 46, 64, 75, 15, 41, 22, 14, 50, 57, 38, 63, 31,
#        55, 46, 22, 55, 55, 41, 55, 31, 55, 14, 55, 50, 22, 37, 14, 41, 40,
#        22, 15, 64, 36, 38, 55, 37, 64, 70, 46, 38, 15, 28, 55, 38, 38, 31,
#        38, 55, 38, 23, 14, 38, 41, 38, 22, 28, 64, 57, 46, 28, 64, 38, 41,
#        46, 57, 64, 41, 41, 55, 46, 52, 38, 57, 55, 64, 55, 52, 38, 52, 31,
#        37, 55, 38, 41, 37, 55, 38, 46, 41, 55, 52, 57, 59, 38, 50, 50, 36,
#        38, 55, 55, 52, 55, 22, 37, 14, 55, 64, 14, 64])

# %%
y
# Out:
# 0      38
# 1      30
# 2      25
# 3      43
# 4      43
#        ..
# 995    40
# 996    67
# 997    16
# 998    57
# 999    37
# Name: writing score, Length: 1000, dtype: int64

# %%
# Input feature values from the user
feature_values = []
for feature_name in X.columns:
    value = input(f"Enter value for {feature_name}: ")
    feature_values.append(float(value))

# Predict the target variable based on user input
predicted_target = classifier.predict([feature_values])

print("Predicted target variable:", predicted_target[0])
# Out:
# Enter value for gender: 1
# Enter value for race/ethnicity: 5
# Enter value for parental level of education: 10
# Enter value for lunch: 5
# Enter value for test preparation course: 7
# Enter value for math score: 10
# Enter value for reading score: 10
# Predicted target variable: 14
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
